# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# %%
import os
os.chdir('P:\SAMPLE DATA')

# %%
start = datetime(2022, 1, 1)
end = datetime(2023, 12, 31)

# %%
england= Point(52.3555, 1.1743, 50)

# %%
data = Daily(england, start, end)
data = data.fetch()

# %%
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
data.to_csv('englans.csv')

# %%
from meteostat import Stations

# %%
stations = Stations()
stations = stations.nearby(52.64698,1.11525)
station = stations.fetch(1)

# %%
print(station)
# Out:
#                          name country region    wmo  icao  latitude  \
# id
# 03492  Norwich Weather Centre      GB    ENG  03492  EGSH   52.6333
#
#        longitude  elevation       timezone hourly_start hourly_end  \
# id
# 03492        1.3       14.0  Europe/London   1987-12-02 2022-03-26
#
#       daily_start  daily_end monthly_start monthly_end      distance
# id
# 03492  1987-12-03 2022-03-23    1996-01-01  2022-01-01  12558.506169

# %%
# Import Meteostat library and dependencies
from datetime import datetime
from meteostat import Hourly

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31, 23, 59)

# Get hourly data
data = Hourly('72219', start, end)
data = data.fetch()

# Print DataFrame
print(data)
#API
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2018-01-01 00:00:00   0.6  -5.6  63.0   NaN   NaN  340.0  18.4   NaN  1024.6
# 2018-01-01 01:00:00  -1.1  -6.6  66.0   0.0   NaN  320.0  16.6   NaN  1025.4
# 2018-01-01 02:00:00  -1.1  -9.5  53.0   0.0   NaN  330.0  22.3   NaN  1025.8
# 2018-01-01 03:00:00  -1.1 -10.0  51.0   0.0   NaN  330.0  25.9   NaN  1025.6
# 2018-01-01 04:00:00  -1.7 -10.5  51.0   0.0   NaN  340.0  18.4   NaN  1026.1
# ...                   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 2018-12-31 19:00:00  20.0  17.2  84.0   0.0   NaN  200.0  18.4   NaN  1016.5
# 2018-12-31 20:00:00  21.1  16.7  76.0   0.0   NaN  190.0  22.3   NaN  1015.8
# 2018-12-31 21:00:00  21.1  16.1  73.0   0.0   NaN  180.0  27.7   NaN  1014.7
# 2018-12-31 22:00:00  21.1  15.0  68.0   0.0   NaN  190.0  27.7   NaN  1015.7
# 2018-12-31 23:00:00  20.0  15.0  73.0   0.0   NaN  180.0  20.5   NaN  1015.6
#
#                      tsun  coco
# ...

# %%
df=pd.read_csv('england.csv')

# %%
df.head()
# Out:
#          time  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# 0  2018-01-01   5.2   3.8   6.7   5.1   NaN  250.0  23.3   NaN   997.4   NaN
# 1  2018-01-02   5.8   1.8  10.2   0.3   NaN  232.0  22.2   NaN  1004.1   NaN
# 2  2018-01-03   7.9   5.5  11.2   6.4   NaN    NaN   NaN   NaN   992.4   NaN
# 3  2018-01-04   6.6   NaN   NaN   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# 4  2018-01-05   4.8   1.3   7.7   1.3   NaN  236.0  17.2   NaN   993.8   NaN

# %%
df.isnull().sum()
# Out:
# time       0
# tavg       1
# tmin       5
# tmax       5
# prcp      42
# wdir       6
# wspd       6
# wpgt     273
# pres       5
# tsun    1461
# dtype: int64

# %%
df.drop('snow',axis=1,inplace=True)

# %%
df.drop('tsun',axis=1,inplace=True)

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Stations, Monthly

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2022, 12, 31)

england= Point(52.3555, 1.1743, 50)

data = Daily(england, start, end)
data = data.fetch()

# %%
data.tail()
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2022-04-01   2.4   0.3   4.9   1.4   NaN   37.0  25.1  48.2  1015.3   NaN
# 2022-04-02   3.2   1.0   5.9   1.6   NaN   43.0  24.1  48.2  1019.5   NaN
# 2022-04-03   3.8   1.3   7.1   1.3   NaN   51.0  23.5  40.8  1020.3   NaN
# 2022-04-04   4.6   1.9   7.5   0.0   NaN   59.0  19.8  38.9  1017.0   NaN
# 2022-04-05   5.5   3.2   8.2   0.0   NaN  343.0  19.1  37.0  1013.1   NaN

# %%
data.isnull().sum()
# Out:
# tavg       2
# tmin       6
# tmax       6
# prcp      43
# snow    1523
# wdir       7
# wspd       7
# wpgt     274
# pres       6
# tsun    1556
# dtype: int64

# %%
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
data.to_csv('month weather.csv')
