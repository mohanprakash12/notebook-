# %%
import os
os.chdir('P:\cloud dep')

# %%
# !pip install pyngrok==4.1.1
# Out:
# 0

# %%
# !pip install -q streamlit
# Out:
# 0

# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 import streamlit as st
#
# File ~\Anaconda3\lib\site-packages\streamlit\__init__.py:70, in <module>
#      68 from streamlit import source_util as _source_util
#      69 from streamlit import string_util as _string_util
# ---> 70 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      71 from streamlit.scriptrunner import (
#      72     add_script_run_ctx as _add_script_run_ctx,
#      73     get_script_run_ctx as _get_script_run_ctx,
#    (...)
#      76     RerunData as _RerunData,
#      77 )
#      78 from streamlit.errors import StreamlitAPIException
#
# File ~\Anaconda3\lib\site-packages\streamlit\delta_generator.py:19, in <module>
#      16 from typing import Optional, Iterable
#      18 import streamlit as st
# ...

# %%
# %%writefile app.py
 
import pickle
import numpy as np
import pandas as pd
import streamlit as st
 
# loading the trained model
pickle_in = open("churnl.pkl", "rb") 
classifier = pickle.load(pickle_in)
 
@st.cache()
  
# defining the function which will make the prediction using the data which the user inputs 
def predict_note_authentication(sales,invoice month, date of invoicing, day of joining, month of joining, year of joning, ProductAreaName, Member Type):   
 
    # Pre-processing user input    
    if(ProductAreaName=='Building Materials'):
        Building Materials = 1
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Contract Services'):
        Building Materials = 0
        Contract Services = 1
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Crop Protection'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 1
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='Feed & Animal Health & Vets Fees'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 1
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Fertiliser'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 1
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Fuel Cards'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 1
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='General Supplies'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 1
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='HH Electricity'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 1
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='Insurance'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 1
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='LPG & Solid Fuel'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 1
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='Liquid Fuel'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 1
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='Liquid fuel (10k + orders)'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 1
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Livestock Products'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 1
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Machinery'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 1
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Non HH Electricity & Mains Gas'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 1
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='Non Service Charge'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 1
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='Rebates'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 1
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Renewables & Steel Buildings'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 1
        Rodenticides = 0
        Seed = 0
        Telecoms =0
    
    elif(ProductAreaName=='Rodenticides'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 1
        Seed = 0
        Telecoms =0
        
    elif(ProductAreaName=='Seed'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 1
        Telecoms =0
    
    elif(ProductAreaName=='Telecoms'):
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms = 1
        
    else:
        Building Materials = 0
        Contract Services = 0
        Crop Protection = 0
        Feed & Animal Health & Vets Fees = 0
        Fertiliser = 0
        Fuel Cards = 0
        General Supplies = 0
        HH Electricity = 0
        Insurance = 0
        LPG & Solid Fuel = 0
        Liquid Fuel = 0
        Liquid fuel (10k + orders) = 0
        Livestock Products = 0
        Machinery = 0
        Non HH Electricity & Mains Gas = 0
        Non Service Charge = 0
        Rebates = 0
        Renewables & Steel Buildings = 0
        Rodenticides = 0
        Seed = 0
        Telecoms = 0
        
    if(Member Type=='2nd Account'):
        2nd Account=1
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
    
    
    elif(Member Type=='Full'):
        2nd Account=0
        Full=1
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
    
    elif(Member Type=='Associate'):
        2nd Account=0
        Full=0
        Associate=1
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Full Plus'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=1
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='AF First Milk'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=1
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
        
    elif(Member Type=='LandServices'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=1
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Staff'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=1
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Agrevise - Full'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=1
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Waitrose Farming Partnership - Full'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=1
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Samco and Shrim'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=1
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Thoroughbred Breeders Association - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=1
        AF PRomote=0
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='AF PRomote'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=1
        Borders Machinery Ring=0 
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Borders Machinery Ring'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=1
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Retired Staff'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=1
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Morrisons - Full'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=1
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Billing Account - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=1
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Shareholders sub account'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=1
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Shareholders sub account'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=1
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
    
    elif(Member Type=='Orion Farming Group - Associat1'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=1
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Waitrose Farming Partnership - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=1
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Highland Business Services'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=1
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
    
    elif(Member Type=='Newsletter'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=1
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Tesco ProducerClub – Full'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=1
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='2nd Account - Full Plus'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=1
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Association of Independent Crop Consultants'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=1
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Tesco ProducerClub – 2nd Acc'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=1
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Tesco ProducerClub – 2nd Acc'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=1
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Billing Account - Full'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=1
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Pembroke Machinery Ring'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=1
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Waitrose Farming Partnership - 2nd Acc'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=1
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
        
    elif(Member Type=='Intergroup'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=1
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Prompt Pay - Full'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=1
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Organic Milk Suppliers Co-operative - Full'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=1
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Tesco ProducerClub – Full Plus'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=1
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Tesco ProducerClub – Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=1
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Buying Groups'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=1
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Agrevise - 2nd Acc'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=1
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Prompt Pay - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=1
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Thames & Kennet Machinery Ring'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=1
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Morrisons - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=1
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Derwent Buying Group - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=1
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Billing Account - Full Plus'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=1
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Organic Milk Suppliers Co-operative – Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=1
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Prompt Pay - Full Plus'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=1
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Aspatria Farmers'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=1
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Lifestyle Charge Card'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=1
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Visit East Anglia - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=1
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Agrevise - Associate'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=1
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='LandServices Waste'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=1
        Special=0
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Special'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=1
        Shareholders sub account - Full Plus=0
        
    elif(Member Type=='Shareholders sub account - Full Plus'):
        2nd Account=0
        Full=0
        Associate=0
        Full Plus=0
        AF First Milk=0
        LandServices=0
        Staff=0
        Agrevise - Full=0
        Waitrose Farming Partnership - Full=0
        Samco and Shrim=0
        Thoroughbred Breeders Association - Associate=0
        AF PRomote=0
        Borders Machinery Ring=0
        Retired Staff=0
        Morrisons - Full=0
        Billing Account - Associate=0
        Shareholders sub account=0
        Orion Farming Group - Associate=0
        Waitrose Farming Partnership - Associate=0
        Highland Business Services=0
        Newsletter=0
        Tesco ProducerClub – Full=0
        2nd Account - Full Plus=0
        Association of Independent Crop Consultants=0
        Tesco ProducerClub – 2nd Acc=0
        Billing Account - Full=0
        Pembroke Machinery Ring=0
        Waitrose Farming Partnership - 2nd Acc=0
        Intergroup=0
        Prompt Pay - Full=0
        Organic Milk Suppliers Co-operative - Full=0
        Tesco ProducerClub – Full Plus=0
        Tesco ProducerClub – Associate=0
        Buying Groups=0
        Agrevise - 2nd Acc=0
        Prompt Pay - Associate=0
        Thames & Kennet Machinery Ring=0
        Morrisons - Associate=0
        Derwent Buying Group - Associate=0
        Billing Account - Full Plus=0
        Organic Milk Suppliers Co-operative – Associate=0
        Prompt Pay - Full Plus=0
        Aspatria Farmers=0
        Lifestyle Charge Card=0
        Visit East Anglia - Associate=0
        Agrevise - Associate=0
        LandServices Waste=0
        Special=0
        Shareholders sub account - Full Plus=1
        
    sales = sales / 1000

    
 
    # Making predictions 
    prediction = classifier.predict( 
        [[sales,invoice month, date of invoicing, day of joining, month of joining, year of joning, Product AreaName, MemberType]])
     
    if payment == 0:
        prediction = 'This user payment might be failed'
    else:
        prediction = 'Payment will be Successfull'
    return prediction
      
# this is the main function in which we define our webpage  
def main():
    st.title("Customer Payment Failure Prediction")
    # front end elements of the web page 
    html_temp = """ 
    <div style ="background-color:yellow;padding:13px"> 
    <h1 style ="color:black;text-align:center;">Streamlit customer payment failure prediciton app</h1> 
    </div> 
    """
      
    # display the front end aspect
    st.markdown(html_temp, unsafe_allow_html = True) 
      
    # following lines create boxes in which user can enter data required to make prediction 
    sales = st.number_input("sales")
    invoice_month = st.number_input("invoice month")
    date_of_invoicing = st.number_input("date of invoicing")
    day_of_joining = st.number_input("day of joining")
    month_of_joining = st.number_input("month of joining")
    year_of_joining = st.number_input("year of joining")
    Product_AreaName = st.selectbox('Product AreaName',("Building Materials","Contract Services","Crop Protection","Feed & Animal Health & Vets Fees",
       "Fertiliser",
      "Fuel Cards",
      "General Supplies",
      "HH Electricity",
       "Insurance",
      "LPG & Solid Fuel",
     "Liquid Fuel",
     "Liquid fuel (10k + orders)",
     "Livestock Products",
     "Machinery",
    "Non HH Electricity & Mains Gas",
    "Non Service Charge",
    "Rebates",
    "Renewables & Steel Buildings",
    "Rodenticides",
    "Seed",
    "Telecoms")) 
    MemberType = st.selectbox('MemberType',("2nd Account", "Full", "Associate", "Full Plus", "AF First Milk",
       "LandServices", "Staff", "Agrevise - Full",
       "Waitrose Farming Partnership - Full", "Samco and Shrim",
       "Thoroughbred Breeders Association - Associate", "AF PRomote",
       "Borders Machinery Ring", "Retired Staff", "Morrisons - Full",
       "Billing Account - Associate", "Shareholders sub account",
       "Orion Farming Group - Associate",
       "Waitrose Farming Partnership - Associate",
       "Highland Business Services", "Newsletter",
       "Tesco ProducerClub – Full", "2nd Account - Full Plus",
       "Association of Independent Crop Consultants",
       "Tesco ProducerClub – 2nd Acc", "Billing Account - Full",
       "Pembroke Machinery Ring",
       "Waitrose Farming Partnership - 2nd Acc", "Intergroup",
       "Prompt Pay - Full", "Organic Milk Suppliers Co-operative - Full",
       "Tesco ProducerClub – Full Plus", "Tesco ProducerClub – Associate",
       "Buying Groups", "Agrevise - 2nd Acc", "Prompt Pay - Associate",
       "Thames & Kennet Machinery Ring", "Morrisons - Associate",
       "Derwent Buying Group - Associate", "Billing Account - Full Plus",
       "Organic Milk Suppliers Co-operative – Associate",
       "Prompt Pay - Full Plus", "Aspatria Farmers",
       "Lifestyle Charge Card", "Visit East Anglia - Associate",
       "Agrevise - Associate", "LandServices Waste", "Special",
       "Shareholders sub account - Full Plus"))
    result =""
      
    if st.button("Predict"):
        if prediction == 1:
            st.warning('Yes, the customer will terminate the service.')
        else:
            st.success('No, the customer is happy with Telco Services.')
   
     
    if __name__=='__main__': 
        main()
# Out:
# Overwriting app.py
# 2022-06-07 13:39:16.822 ERROR   pyngrok.process: t=2022-06-07T13:39:16+0100 lvl=eror msg="session closed, starting reconnect loop" obj=csess id=e5ba0f1218f4 err="read tcp 192.168.0.138:59540->3.12.62.205:443: wsarecv: An established connection was aborted by the software in your host machine."
#
# 2022-06-07 13:39:16.855 ERROR   pyngrok.process: t=2022-06-07T13:39:16+0100 lvl=eror msg="failed to reconnect session" obj=csess id=e5ba0f1218f4 err="dial tcp: lookup tunnel.us.ngrok.com: no such host"
#
# 2022-06-07 13:39:17.350 ERROR   pyngrok.process: t=2022-06-07T13:39:17+0100 lvl=eror msg="failed to reconnect session" obj=csess id=e5ba0f1218f4 err="dial tcp: lookup tunnel.us.ngrok.com: no such host"
#
# 2022-06-07 13:39:19.062 INFO    pyngrok.process: t=2022-06-07T13:39:19+0100 lvl=info msg="tunnel session started" obj=tunnels.session
#
# ...

# %%
get_ipython().system = os.system

# %%
# !streamlit run app.py &>/dev/null&
# Out:
# 1

# %%
from pyngrok import ngrok
public_url = ngrok.connect(port='8501')

# %%
public_url
# Out:
# 'http://bd2e-185-83-13-34.ngrok.io'
